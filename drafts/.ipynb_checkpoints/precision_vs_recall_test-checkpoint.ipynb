# %%
import pandas as pd
import seaborn as sns

# %%
origin = pd.read_csv("../dataset/results-2021-12-18.csv")
origin
# Out:
#                algorithm   RQ  experiment_id  iteration  no_datapoints  \
# 0               AdaBoost  2.1            103          2           2730
# 1          Decision Tree  2.2             33          2           3900
# 2                    SVM  2.2             15         22           3900
# 3               AdaBoost  2.2            112          1           3900
# 4     Bagging Classifier  2.2            138          6           3900
# ...                  ...  ...            ...        ...            ...
# 3595       Random Forest  2.2             96          2           3900
# 3596  Bagging Classifier  2.1            126         20           1559
# 3597                 SVM  2.2             17         19           3900
# 3598       Random Forest  2.1             86         18           1559
# 3599            AdaBoost  2.1            110         17           3900
#
#       no_features  preprocessing_energy(J)  preprocessing_time(s)  \
# ...

# %%
sns.set_theme(style="white")
sns.relplot(data=origin, x="precision", y="recall", hue="algorithm", alpha=0.1)
