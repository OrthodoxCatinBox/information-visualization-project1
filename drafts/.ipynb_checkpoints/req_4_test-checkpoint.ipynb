# %%
import pandas as pd
import numpy as np

# %%
origin = pd.read_csv("../dataset/results-2021-12-18.csv")
origin
# Out:
#                algorithm   RQ  experiment_id  iteration  no_datapoints  \
# 0               AdaBoost  2.1            103          2           2730
# 1          Decision Tree  2.2             33          2           3900
# 2                    SVM  2.2             15         22           3900
# 3               AdaBoost  2.2            112          1           3900
# 4     Bagging Classifier  2.2            138          6           3900
# ...                  ...  ...            ...        ...            ...
# 3595       Random Forest  2.2             96          2           3900
# 3596  Bagging Classifier  2.1            126         20           1559
# 3597                 SVM  2.2             17         19           3900
# 3598       Random Forest  2.1             86         18           1559
# 3599            AdaBoost  2.1            110         17           3900
#
#       no_features  preprocessing_energy(J)  preprocessing_time(s)  \
# ...

# %%
np.linspace(0, 1, 11)[3]
# Out:
# 0.30000000000000004

# %%
test = origin.groupby(["no_datapoints", "no_features", "algorithm"]).mean()["train_energy(J)"]
[list(k) + [w, v] for k, v in test.items() for w in np.linspace(0, 1, 11)]
# Out:
# [[389, 8169, 'AdaBoost', 0.0, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.1, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.2, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.30000000000000004, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.4, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.5, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.6000000000000001, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.7000000000000001, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.8, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 0.9, 0.11320586077137366],
#  [389, 8169, 'AdaBoost', 1.0, 0.11320586077137366],
#  [389, 8169, 'Bagging Classifier', 0.0, 0.07554122292767788],
#  [389, 8169, 'Bagging Classifier', 0.1, 0.07554122292767788],
#  [389, 8169, 'Bagging Classifier', 0.2, 0.07554122292767788],
#  [389, 8169, 'Bagging Classifier', 0.30000000000000004, 0.07554122292767788],
#  [389, 8169, 'Bagging Classifier', 0.4, 0.07554122292767788],
# ...

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
